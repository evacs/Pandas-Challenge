# %% [markdown]
# # PyCity Schools Analysis
#
# - The following analysis shows the performance of several schools and investigates some possible factors that could contribute to passing rates. The factors include:
#     - School type (charter/district)
#     - School size (# of students)
#     - Budget per student
# - From the comparisons, I've drawn the following conclusions:
#     - Charter schools outperform district schools, especially in math scores.
#     - Medium size schools perform better than both large and small schools. There are no small district schools, but
#     there is one large charter school. This school performed very highly. This indicates that the size of the school
#     isn't a significant contributing factor, but rather the school type is.
#     - Surprisingly, the higher the budget per student, the lower the overall performance of the school. The charter
#     schools typically had lower spending budgets, so once again, performance seems to be based mostly on school type.
#     - School type is the largest contributing factor to higher student passing rates over school size and budget per
#     student.
#
# ---

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary

# %%
# Calculate the total number of unique schools
unique_schools = school_data_complete.school_name.unique()
school_count = len(unique_schools)
school_count
# Out:
# 15

# %%
# Calculate the total number of students
student_count = len(school_data_complete)
student_count
# Out:
# 39170

# %%
unique_budget = school_data_complete.budget.unique() # this would fail if more than one school had the same budget
len(unique_budget) #this ensures that the number of unique budgets and schools matches, if it did not, i would have 
                    #probably iterated in a conditional for loop
# Out:
# 15

# %%
# Calculate the total budget
total_budget = sum(unique_budget)
total_budget
# Out:
# 24649428

# %%
# Calculate the average (mean) math score
average_math_score = school_data_complete['math_score'].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
# Calculate the average (mean) reading score
average_reading_score = school_data_complete['reading_score'].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
# Use the following to calculate the percentage of students who passed math (math scores greather than or equal to 70)
passing_math_count = school_data_complete[(school_data_complete["math_score"] >= 70)].count()["student_name"]
passing_math_percentage = passing_math_count / float(student_count) * 100
passing_math_percentage
# Out:
# 74.9808526933878

# %%
# Calculate the percentage of students who passed reading (hint: look at how the math percentage was calculated)  
passing_reading_count = school_data_complete[(school_data_complete["reading_score"] >= 70)].count()["student_name"]
passing_reading_percentage = passing_reading_count / float(student_count) * 100
passing_reading_percentage
# Out:
# 85.80546336482001

# %%
# Use the following to calculate the percentage of students that passed math and reading
passing_math_reading_count = school_data_complete[
    (school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)
].count()["student_name"]
overall_passing_rate = passing_math_reading_count /  float(student_count) * 100
overall_passing_rate
# Out:
# 65.17232575950983

# %%
# Create a high-level snapshot of the district's key metrics in a DataFrame
keys = ['Total Schools','Total Students','Total Budget','Average Math Score','Average Reading score',
        '% Passing Math','% Passing Reading','Overall Passing']
data = [[15,student_count,total_budget,round(average_math_score,2),round(average_reading_score,2),
         round(passing_math_percentage,2),round(passing_reading_percentage,2),round(overall_passing_rate,2)]]
district_summary = pd.DataFrame(data, columns=keys)

# Formatting
district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,.2f}".format)

# Display the DataFrame
district_summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00               78.99
#
#    Average Reading score  % Passing Math  % Passing Reading  Overall Passing
# 0                  81.88           74.98              85.81            65.17

# %% [markdown]
# ## School Summary

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# Use the code provided to select all of the school types
school_types = school_data_complete.type.unique()
school_types
# Out:
# array(['District', 'Charter'], dtype=object)

# %%
# Creating a df based on schools
def filtered_data(df):
    school_data = []
    student_pop = int
    
    for i in range(len(df)):
        school_data_complete.query('school_name'==unique_schools[i])

# %%
# to use as conditinal later
unique_schools = unique_schools.astype(str)
unique_schools
# Out:
# array(['Huang High School', 'Figueroa High School', 'Shelton High School',
#        'Hernandez High School', 'Griffin High School',
#        'Wilson High School', 'Cabrera High School', 'Bailey High School',
#        'Holden High School', 'Pena High School', 'Wright High School',
#        'Rodriguez High School', 'Johnson High School', 'Ford High School',
#        'Thomas High School'], dtype='<U21')

# %%
# getting data on one school, experimenting with different things
df = school_data_complete[(school_data_complete['school_name']==unique_schools[0])]
df.head()
#sch_type =  ', '.join(df['type'].unique())
sch_type = df.iloc[0,8]
print(sch_type)
pop = len(df)
print(pop)
print(df.iloc[0,9])
# bpc = unique_budget[0]/pop
bpc = df.iloc[0,10]/pop
print(bpc)
avg_math = round(df['math_score'].mean(),2)
avg_reading = round(df['reading_score'].mean(),2)
pass_math = df[(df["math_score"] >= 70)].count()["student_name"]
pass_read = df[(df["reading_score"] >= 70)].count()["student_name"]
overall_pass = df[(df["reading_score"] >= 70) & (df["math_score"] >= 70)].count()["student_name"]
pass_rate = round(overall_pass/float(pop) * 100, 2)
print(avg_math,avg_reading,pass_math,pass_read, overall_pass, pass_rate)
# Out:
# District
# 2917
# 2917
# 655.0
# 76.63 81.18 1916 2372 1561 53.51

# %%
#function to automate all needed data to create a new df

def get_stats(df,lst):
    data = []    

    for i in range(15):
        school = []
        df = school_data_complete[(school_data_complete['school_name']==lst[i])]
        sch_type = df.iloc[0,8]
        pop = df.iloc[0,9]
        total = df.iloc[0,10]
        bpc = round(total/pop,2)
        avg_math = round(df['math_score'].mean(),2)
        avg_reading = round(df['reading_score'].mean(),2)
        pass_math = df[(df["math_score"] >= 70)].count()["student_name"]
        math_perc = round(pass_math/pop * 100,2)        
        pass_read = df[(df["reading_score"] >= 70)].count()["student_name"]
        read_perc = round(pass_read/pop * 100,2)
        overall_pass = df[(df["reading_score"] >= 70) & (df["math_score"] >= 70)].count()["student_name"]
        pass_rate = round(overall_pass/float(pop) * 100, 2)
        school.append(lst[i])
        school.append(sch_type)
        school.append(pop)
        school.append(total)
        school.append(bpc)
        school.append(avg_math)
        school.append(avg_reading)
#         school.append(pass_math)
#         school.append(pass_read)
        school.append(math_perc)
        school.append(read_perc)
        #school.append(overall_pass)
        school.append(pass_rate)
        data.append(school)
    return data

# %%
school_stats = get_stats(school_data_complete, unique_schools)

# %%
# # Use the provided code to calculate the passing rates
# per_school_passing_math = school_students_passing_math / per_school_counts * 100
# per_school_passing_reading = school_students_passing_reading / per_school_counts * 100
# overall_passing_rate = school_students_passing_math_and_reading / per_school_counts * 100

# %%
# Create a DataFrame called `per_school_summary` with columns for the calculations above.
per_school_summary = pd.DataFrame(school_stats, columns = ('school','School Type','Total Students','Total School Budget',
                                                           'Per Student Budget','Average Math Score','Average Reading Score',
                                                           '% Passing Math','% Passing Reading','% Overall Passing'))
per_school_summary.set_index('school', inplace=True)
per_school_summary.index.name = None


# Formatting
per_school_summary["Total School Budget"] = per_school_summary["Total School Budget"].map("${:,.2f}".format)
per_school_summary["Per Student Budget"] = per_school_summary["Per Student Budget"].map("${:,.2f}".format)

# Display the DataFrame
per_school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Bailey High School       District            4976       $3,124,928.00
# Holden High School        Charter             427         $248,087.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %% [markdown]
# ## Highest-Performing Schools (by % Overall Passing)

# %%
# Sort the schools by `% Overall Passing` in descending order and display the top 5 rows.
top_schools = per_school_summary.sort_values('% Overall Passing', ascending=False)
top_schools.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00               83.06
# Thomas High School             $638.00               83.42
# Griffin High School            $625.00               83.35
# Wilson High School             $578.00               83.27
# Pena High School               $609.00               83.84
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School                  83.98           94.13              97.04
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %%
# Sort the schools by `% Overall Passing` in ascending order and display the top 5 rows.
bottom_schools = top_schools = per_school_summary.sort_values('% Overall Passing', ascending=True)
bottom_schools.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00               76.84
# Figueroa High School             $639.00               76.71
# Huang High School                $655.00               76.63
# Hernandez High School            $652.00               77.29
# Johnson High School              $650.00               77.07
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School                  80.74           66.37
# ...

# %% [markdown]
# ## Math Scores by Grade

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group by `school_name` and take the mean of the `math_score` column for each.
ninth_grade_math_scores = ninth_graders.groupby('school_name')['math_score'].mean()
tenth_grader_math_scores = tenth_graders.groupby('school_name')['math_score'].mean()
eleventh_grader_math_scores = eleventh_graders.groupby('school_name')['math_score'].mean()
twelfth_grader_math_scores = twelfth_graders.groupby('school_name')['math_score'].mean()

# Combine each of the scores above into single DataFrame called `math_scores_by_grade`
keys = ["9th","10th", "11th", "12th"]
math_scores_by_grade = pd.merge(pd.merge(pd.merge(ninth_grade_math_scores,tenth_grader_math_scores, on='school_name'),
                                                 eleventh_grader_math_scores, on = 'school_name'),
                                twelfth_grader_math_scores, on = 'school_name')

# Minor data wrangling
math_scores_by_grade.index.name = None
math_scores_by_grade.columns = keys

# Display the DataFrame
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group by `school_name` and take the mean of the the `reading_score` column for each.
ninth_grade_reading_scores = ninth_graders.groupby('school_name')['reading_score'].mean()
tenth_grader_reading_scores = tenth_graders.groupby('school_name')['reading_score'].mean()
eleventh_grader_reading_scores = eleventh_graders.groupby('school_name')['reading_score'].mean()
twelfth_grader_reading_scores = twelfth_graders.groupby('school_name')['reading_score'].mean()

# Combine each of the scores above into single DataFrame called `reading_scores_by_grade`
keys = ["9th","10th", "11th", "12th"]
reading_scores_by_grade = pd.merge(pd.merge(pd.merge(ninth_grade_reading_scores,tenth_grader_reading_scores, on='school_name'),
                                                 eleventh_grader_reading_scores, on = 'school_name'),
                                twelfth_grader_reading_scores, on = 'school_name')

# Minor data wrangling
reading_scores_by_grade.columns = keys
reading_scores_by_grade.index.name = None

# Display the DataFrame
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %%
# Establish the bins 
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
# Create a copy of the school summary since it has the "Per Student Budget" 
school_spending_df = per_school_summary.copy()
school_spending_df.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
#
#                       Per Student Budget  Average Math Score  \
# Huang High School                $655.00               76.63
# Figueroa High School             $639.00               76.71
# Shelton High School              $600.00               83.36
# Hernandez High School            $652.00               77.29
# Griffin High School              $625.00               83.35
#
#                        Average Reading Score  % Passing Math  \
# Huang High School                      81.18           65.68
# ...

# %%
# Changing Per Student Budget to numeric for calculations after errors
df = per_school_summary.copy()
df["Per Student Budget"] = df["Per Student Budget"].map(lambda x: x.lstrip('$')) #obtained from chatgpt
df["Per Student Budget"] = pd.to_numeric(df['Per Student Budget'], errors='coerce')
df.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
#
#                        Per Student Budget  Average Math Score  \
# Huang High School                   655.0               76.63
# Figueroa High School                639.0               76.71
# Shelton High School                 600.0               83.36
# Hernandez High School               652.0               77.29
# Griffin High School                 625.0               83.35
#
#                        Average Reading Score  % Passing Math  \
# Huang High School                      81.18           65.68
# ...

# %%
# Use `pd.cut` to categorize spending based on the bins.
school_spending_df = df
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(school_spending_df["Per Student Budget"],
                                                             bins = spending_bins, labels = labels)
school_spending_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Bailey High School       District            4976       $3,124,928.00
# Holden High School        Charter             427         $248,087.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %%
#  Calculate averages for the desired columns. 
spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Math Score"].mean()
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
spending_passing_math = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Passing Math"].mean()
spending_passing_reading = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Passing Reading"].mean()
overall_passing_spending = school_spending_df.groupby(["Spending Ranges (Per Student)"])["% Overall Passing"].mean()

# %%
# Assemble into DataFrame
var = 'Spending Ranges (Per Student)'
spending_summary = pd.merge(pd.merge(pd.merge(pd.merge(spending_math_scores,spending_reading_scores,
                                                       on = var),spending_passing_math, on = var),
                                     spending_passing_reading, on = var), overall_passing_spending, on = var)
                                     
                                     

# Display results
spending_summary
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.452500              83.935000
# $585-630                                81.900000              83.155000
# $630-645                                78.517500              81.625000
# $645-680                                76.996667              81.026667
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460000          96.610000
# $585-630                            87.132500          92.717500
# $630-645                            73.485000          84.392500
# $645-680                            66.163333          81.133333
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  90.367500
# $585-630                               81.417500
# ...

# %% [markdown]
# ## Scores by School Size

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Categorize the spending based on the bins
# Use `pd.cut` on the "Total Students" column of the `per_school_summary` DataFrame.

per_school_summary["School Size"] = pd.cut(per_school_summary["Total Students"],
                                                             bins = size_bins, labels = labels)
per_school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Shelton High School       Charter            1761       $1,056,600.00
# Hernandez High School    District            4635       $3,022,020.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Bailey High School       District            4976       $3,124,928.00
# Holden High School        Charter             427         $248,087.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %%
# Calculate averages for the desired columns. 
size_math_scores = per_school_summary.groupby(["School Size"])["Average Math Score"].mean()
size_reading_scores = per_school_summary.groupby(["School Size"])["Average Reading Score"].mean()
size_passing_math = per_school_summary.groupby(["School Size"])["% Passing Math"].mean()
size_passing_reading = per_school_summary.groupby(["School Size"])["% Passing Reading"].mean()
size_overall_passing = per_school_summary.groupby(["School Size"])["% Overall Passing"].mean()

# %%
# Create a DataFrame called `size_summary` that breaks down school performance based on school size (small, medium, or large).
# Use the scores above to create a new DataFrame called `size_summary`
var = 'School Size'
size_summary = pd.merge(pd.merge(pd.merge(pd.merge(size_math_scores,size_reading_scores,
                                                       on = var),size_passing_math, on = var),
                                     size_passing_reading, on = var), size_overall_passing, on = var)

# Display results
size_summary
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                   83.820               83.92500        93.55000
# Medium (1000-2000)              83.374               83.86800        93.59800
# Large (2000-5000)               77.745               81.34375        69.96375
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)                96.10000             89.885
# Medium (1000-2000)           96.79000             90.620
# Large (2000-5000)            82.76625             58.285

# %% [markdown]
# ## Scores by School Type

# %%
# Group the per_school_summary DataFrame by "School Type" and average the results.
average_math_score_by_type = per_school_summary.groupby(["School Type"])["Average Math Score"].mean()
average_reading_score_by_type = per_school_summary.groupby(["School Type"])["Average Reading Score"].mean()
average_percent_passing_math_by_type = per_school_summary.groupby(["School Type"])["% Passing Math"].mean()
average_percent_passing_reading_by_type = per_school_summary.groupby(["School Type"])["% Passing Reading"].mean()
average_percent_overall_passing_by_type = per_school_summary.groupby(["School Type"])["% Overall Passing"].mean()

# %%
# Assemble the new data by type into a DataFrame called `type_summary`
var = 'School Type'
type_summary = pd.merge(pd.merge(pd.merge(pd.merge(average_math_score_by_type, average_reading_score_by_type,
                                                   on = var), average_percent_passing_math_by_type, on = var),
                                 average_percent_passing_reading_by_type, on = var),
                        average_percent_overall_passing_by_type, on = var)

# Display results
type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.472500              83.897500       93.620000
# District              76.955714              80.965714       66.548571
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586250          90.431250
# District             80.798571          53.671429
